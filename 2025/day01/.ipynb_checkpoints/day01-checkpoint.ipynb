# %%
import os
import sys
import importlib

import pandas as pd

repos_aoc_2025_dir = os.path.dirname(os.path.abspath(os.getcwd()))
sys.path.append(os.path.join(repos_aoc_2025_dir, 'day01'))
import utils

# %%
importlib.reload(utils)
input_txt = os.path.join(repos_aoc_2025_dir, "day01", "input_.txt")
ranges, ingredient_ids = utils.load_data(input_txt)

# %%
ranges
# Out:
#    start  end
# 0     10   14
# 1     16   20
# 2     12   18
